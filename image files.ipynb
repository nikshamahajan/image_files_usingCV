# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\NIKSHA MAHAJAN\Pictures\Suga painting.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (429, 643, 3)

# %%
plt.imshow(img)

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray=cv2.imread(r"C:\Users\NIKSHA MAHAJAN\Pictures\Suga painting.jpg",cv2.IMREAD_GRAYSCALE)

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)

# %%
new_img=cv2.resize(fix_img,(200,400))

# %%
plt.imshow(new_img)

# %%
w_ratio=0.5
h_ratio=0.5

# %%
new_img=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img=cv2.flip(fix_img,0)
plt.imshow(new_img)
